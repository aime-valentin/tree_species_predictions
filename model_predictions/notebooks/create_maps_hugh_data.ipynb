# %%
import pandas as pd
import numpy as np
import spectral as sp
import joblib
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
#import model
model = joblib.load('../models/species_hyper_ind_nd_aug.joblib')

# %%
#import aug bands
aug = pd.read_csv("../data/aug_cols.csv",index_col = 0)
imp_bands = list(aug.columns[2:-1])

# %%
#import hierarchical classification results\
hdr_class = sp.envi.open("../data/EastCampus_TreeCanopies.hdr")
wvl_class = hdr_class.bands.centers
rows_class, cols_class, bands_class = hdr_class.nrows, hdr_class.ncols, hdr_class.nbands
meta_ = hdr_class.metadata

# %%
#import hyperspectral data
hdr = sp.envi.open("../data/campus_warp_ref_20180802-181620-KES-1-EC-rect.hdr")
wvl = hdr.bands.centers
rows, cols, bands = hdr.nrows, hdr.ncols, hdr.nbands
meta = hdr.metadata

# %%
#initialize a matrix to hold predictions ( 2294 x 10039 x 1 matrix)
preds = np.zeros((rows_class,cols_class,1))
all_pixel_ct = 0
tre_pixel_ct = 0 
#loop throught August Image pixel by pixel
for x in range(rows):
    for y in range(cols):
        #take one pixel and create a dataframe with wavelengths as columns
        #and reflectance as rows (data)
        pixel = hdr.read_pixel(x, y)
        temp_df = pd.DataFrame.from_dict({key:[row] for key, row in zip(wvl,pixel)})
        temp_df.rename(columns ={key:val for key, val in zip(temp_df.columns,[str(round(float(i))) for i in temp_df.columns])},
                      inplace = True)
        class_cur = int(hdr_class.read_pixel(x,y)[0])
       
        #if pixel is classified as 2
        #use the model to predict its species
        if class_cur ==1:
            temp_df2 = temp_df[[str(round(float(i))) for i in imp_bands]]
            new_class = model.predict([list(temp_df2.iloc[0])])
            preds[x][y][0] = new_class[0]
            
            tre_pixel_ct +=1
            with open('tree_class_progress.txt', 'w+') as tp:
                tp.write(f'{tre_pixel_ct}/3380949 or {round((tre_pixel_ct/3380949)*100)}%')
            
        else:
            preds[x][y][0] = 100
        
        #track progress
        all_pixel_ct +=1
        with open('overall_progress.txt', 'w+') as op:
            op.write(f'{all_pixel_ct}/3380949 or {round((all_pixel_ct/3380949)*100)}%')
# Out:
# [Parallel(n_jobs=40)]: Using backend ThreadingBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=40)]: Using backend ThreadingBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=40)]: Using backend ThreadingBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=40)]: Using backend ThreadingBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=40)]: Using backend ThreadingBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=40)]: Using backend ThreadingBackend with 40 concurrent workers.
# [Parallel(n_jobs=40)]: Done 100 out of 100 | elapsed:    0.0s finished
# ...

# %%
#save the predictions
sp.envi.save_classification("../data/output/EastCampus_TreeCanopies_predictions.hdr",
       preds,dtype=np.uint8, metadata = meta_ )
